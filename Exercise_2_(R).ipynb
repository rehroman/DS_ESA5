# %% [markdown]
# Exercise 2 (R)
#
# Analyse the esoph dataset. Can you derive some useful statements from it? Use data() to see all available datasets.

# %% [markdown]
# esoph data set: Data from a case-control study of (o)esophageal cancer in Ille-et-Vilaine, France.

# %%
# generelle Informationen
summary(esoph)
# Out:
#    agegp          alcgp         tobgp        ncases         ncontrols
#  25-34:15   0-39g/day:23   0-9g/day:24   Min.   : 0.000   Min.   : 0.000
#  35-44:15   40-79    :23   10-19   :24   1st Qu.: 0.000   1st Qu.: 1.000
#  45-54:16   80-119   :21   20-29   :20   Median : 1.000   Median : 4.000
#  55-64:16   120+     :21   30+     :20   Mean   : 2.273   Mean   : 8.807
#  65-74:15                                3rd Qu.: 4.000   3rd Qu.:10.000
#  75+  :11                                Max.   :17.000   Max.   :60.000

# %%
boxplot(esoph$ncases ~ esoph$agegp)
# Out:
# plot without title

# %%
# der Chart zeigt, dass die höchste Anzahl an Speiseröhrenkrebsfällen in der Altergruppe 65-74 auftreten

# %%
boxplot(esoph$ncases ~ esoph$alcgp)
# Out:
# plot without title

# %%
# Die meisten Fälle treten bei Konsum von 40-79g/Tag Alkoholkonsum auf

# %%
boxplot(esoph$ncases ~ esoph$tobgp)
# Out:
# plot without title

# %%
# Ein Zusammenhang zum Rauchen ist nicht klar erkennbar.
